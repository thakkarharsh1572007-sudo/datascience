# %%
print("my name is Thakkar Harsh mukeshbhai \nmy favorite app is instagam")
# Out:
# my name is Thakkar Harsh mukeshbhai
# my favorite app is instagam

# %%
print("welcome to datascience with python!")
# Out:
# welcome to datascience with python!
