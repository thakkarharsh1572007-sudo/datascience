# %% [markdown]
# # question 1

# %%
time = float(input("enter your spodify listing time in minetes"))
if time > 120 :
    print("You are a true music fan!")
else :
    print ("Keep listening!")
# Out:
# Keep listening!

# %% [markdown]
# # question 2

# %%
amount = float(input("enter your order amount :"))
if amount > 300 :
    print ("Eligible for free delivery")
else :
    print ("Delivery charges apply")
# Out:
# Delivery charges apply

# %% [markdown]
# # question 3

# %%
cart = float(input("enter your cart amount"))
if cart > 2000:
    print ("you got 10% discount ")
    cart -= cart*10/100
elif cart > 1000:
    print ("you got 5% discount")
    cart -= cart*5/100
else :
    print ("no discount available")
print(f"your final amount {cart}")
# Out:
# you got 10% discount
# your final amount 37800.0

# %% [markdown]
# # question 4

# %%
point = float(input("enter your IPL fantacy point :"))
if point > 800 :
    print ("Champion")
else :
    if point > 500 :
        print ("Top Performer")
    else :
        print ("Keep Trying")
# Out:
# Champion
