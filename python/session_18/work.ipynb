# %% [markdown]
# # question 1

# %%
import re 
text = "Contact the Mumbai branch at +91-9876543210 or email them at support.mumbai@example.in. The office was officially established on 15/08/1995. For our New Delhi headquarters, reach out via hr_delhi@company.co.in or call the landline at 011-23456789. The upcoming annual tech conference is scheduled for 2026-12-10 in Bengaluru, Karnataka (Pincode: 560001). Early bird tickets are priced at INR 4,500, while VIP passes cost ₹12,000. Please ensure all invoices are submitted to finance-dept@example.com by the end of the month."

# %%
a = re.findall(r"\+91-\d{10}",text)
a
# Out:
# ['+91-9876543210']

# %% [markdown]
# # question 2

# %%
b = re.search(r"\d{2,4}/\d{2}/\d{2,4}",text)
print(b)
# Out:
# <re.Match object; span=(129, 139), match='15/08/1995'>

# %% [markdown]
# # question 3

# %%
txt = "rs 1025 rs 205 rs 3030"
c = re.findall(r"rs +\d+",txt)
total = 0
for i in c :
    t = i.removeprefix("rs ")
    t = int(t)
    total = total + t
print(total)
# Out:
# 4260

# %% [markdown]
# # question 4

# %%
d = re.sub(r"[a-zA-Z0-9.-]+@[a-z.]+.[a-z]{2,}","[hidden email]",text)
d
# Out:
# 'Contact the Mumbai branch at +91-9876543210 or email them at [hidden email]. The office was officially established on 15/08/1995. For our New Delhi headquarters, reach out via hr_[hidden email] call the landline at 011-23456789. The upcoming annual tech conference is scheduled for 2026-12-10 in Bengaluru, Karnataka (Pincode: 560001). Early bird tickets are priced at INR 4,500, while VIP passes cost ₹12,000. Please ensure all invoices are submitted to [hidden email] the end of the month.'

# %% [markdown]
# # question 5

# %%
te = "Say hi to @alex, @john_doe, and @su. Don't forget @dev_99!"
e = re.findall(r"@\w{3,}",te)
e
# Out:
# ['@alex', '@john_doe', '@dev_99']
