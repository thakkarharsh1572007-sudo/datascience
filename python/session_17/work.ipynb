# %% [markdown]
# # question 1

# %%
from math import sqrt
print(sqrt(225))
# Out:
# 15.0

# %% [markdown]
# # question 2

# %%
import os 
os.mkdir('MyDownloads')

# %%
os.path.abspath('MyDownloads')
# Out:
# 'c:\\Users\\Dell\\Desktop\\data science\\session_17\\MyDownloads'

# %% [markdown]
# # question 3

# %%
import datetime
print("you run this code at ",datetime.datetime.now())
# Out:
# you run this code at  22:17:48.340725

# %% [markdown]
# # question 4

# %%
import playlist_utils as pu 
print(pu.playlist)
pu.add_in_playlist("hfnj")
print(pu.playlist)
# Out:
# ['kfnnvj', 'mvknkfnv', 'kvnvnnv', 'jkvnfv']
# ['kfnnvj', 'mvknkfnv', 'kvnvnnv', 'jkvnfv', 'hfnj']

# %% [markdown]
# # question 5
