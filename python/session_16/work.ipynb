# %% [markdown]
# # Question 1

# %%
app = ["amazon","filpcart","instagram","zomato","whatsapp"]
a = iter(app)
while a :
    print(next(a))
# Out:
# amazon
# filpcart
# instagram
# zomato
# whatsapp
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[2], line 4
#       1 app = ["amazon","filpcart","instagram","zomato","whatsapp"]
#       2 a = iter(app)
#       3 while a :
# ----> 4     print(next(a))
#
# StopIteration:

# %% [markdown]
# # Question 2

# %%
def play_playlist (playlist):
    for i in playlist:
        yield i+" is palying .......................\n....................................."
a = play_playlist(['jfngj','jghgnb',' dn vn m '])
while a  :
    print(next(a))
# Out:
# jfngj is palying .......................
# .....................................
# jghgnb is palying .......................
# .....................................
#  dn vn m  is palying .......................
# .....................................
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[1], line 6
#       2     for i in playlist:
#       3         yield i+" is palying .......................\n....................................."
#       4 a = play_playlist(['jfngj','jghgnb',' dn vn m '])
#       5 while a  :
# ----> 6     print(next(a))
#
# StopIteration:

# %% [markdown]
# # Question 3

# %%
a = ['Pizza', 'Burger', 'Fries', 'Coke']
for i,j in enumerate(a,start=1):
    print(i,j)
# Out:
# 1 Pizza
# 2 Burger
# 3 Fries
# 4 Coke

# %% [markdown]
# # Question 4

# %%
team = ['csk','mi','psk','gt','rcb']
points = [12,13,14,16,11]
teamwithPoints = zip(team,points)
for i in teamwithPoints:
    print(i)
# Out:
# ('csk', 12)
# ('mi', 13)
# ('psk', 14)
# ('gt', 16)
# ('rcb', 11)

# %% [markdown]
# # Question 5

# %%
order_id = 1000
def orderIdGenerator ():
    while True  :
        global order_id
        order_id+= 1
        yield order_id 
a = orderIdGenerator()

# %%
print ("generate order id \n ",next(a))
# Out:
# generate order id
#   1001
