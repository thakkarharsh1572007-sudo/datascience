# %% [markdown]
# # Question 1

# %%
item_price = 250 
delivery_fee = 30
coupon_discount = 20
print (f"in this product the price is {item_price} and delivey fee is {delivery_fee} and coupon discoun is {coupon_discount}")
# Out:
# in this product the price is 250 and delivey fee is 30 and coupon discoun is 20

# %% [markdown]
# # Question 2

# %%
product_price = int(input("enter product price :"))
if product_price >= 1000 :
    print("free delivery")
else :
    print("delivery charge apply")
# Out:
# delivery charge apply

# %% [markdown]
# # Question 3

# %%
# this is single line comment
''' this 
is 
multiline 

comment
'''
a=10
a
# Out:
# 10

# %% [markdown]
# # Question 4

# %%
team_name = "csk "
run_scroad = 123
over_plyed = 12
print (f" team name {team_name} over plyed : {over_plyed} and  runs : {run_scroad}")
# Out:
#  team name csk  over plyed : 12 and  runs : 123
