# %% [markdown]
# # question 1

# %%
food_dilivery_app = ["swiggy","zometo","toining","zepto","instamart"]
for i in food_dilivery_app :
    print (i)
# Out:
# swiggy
# zometo
# toining
# zepto
# instamart

# %% [markdown]
# # question 2

# %%
dailly_step_count = [1000,5858,6593,4825,65266,4582,1525,3232,6595,4876,362325,152514,132535,66665]
i=0
while dailly_step_count[i] < 10000:
    i+=1
print(f'at the day {i} uoy first cross 10000 steps')
# Out:
# at the day 4 uoy first cross 10000 steps

# %% [markdown]
# # question 3

# %%
ipl_team = ['kings','royals','indians','titans','gients','super kings']
def ipl_team_morethen_6_cherector (ipl_team):
    for i in ipl_team :
        if len(i) > 6:
            print(i)
        else :
            continue 
ipl_team_morethen_6_cherector(ipl_team)
# Out:
# indians
# super kings

# %% [markdown]
# # question 4

# %%
song_durations = [125,568,62,659,125,148,175,254,354,358,369,357,458,468]
for i,song in enumerate(song_durations,start=1):
    print (f"song {i} : {song}")
# Out:
# song 1 : 125
# song 2 : 568
# song 3 : 62
# song 4 : 659
# song 5 : 125
# song 6 : 148
# song 7 : 175
# song 8 : 254
# song 9 : 354
# song 10 : 358
# song 11 : 369
# song 12 : 357
# song 13 : 458
# song 14 : 468

# %% [markdown]
# # question 5

# %%
flipcart_cart = [152,352,650,1120,0]
sum = 0
for i in flipcart_cart:
    if sum < 2000 :
        if i>0:
            sum += i
        else :
            continue
    else :
        break 
print (f"your cart total is {sum}")
# Out:
# your cart total is 2274
