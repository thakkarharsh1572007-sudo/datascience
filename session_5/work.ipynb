# %% [markdown]
# # question 1

# %%
IDs = [240,356,895,6523,67,9]
IDs
# Out:
# [240, 356, 895, 6523, 67, 9]

# %% [markdown]
# # question 2

# %%
playlist_IDs = []
playlist_IDs.extend(IDs)
playlist_IDs.append(285)
playlist_IDs
# Out:
# [240, 356, 895, 6523, 67, 9, 285]

# %% [markdown]
# # question 3

# %%
a = playlist_IDs.pop()
print(f'song playing : {a} and remaing song : {playlist_IDs}')
# Out:
# song playing : 285 and remaing song : [240, 356, 895, 6523, 67, 9]

# %% [markdown]
# # question 4

# %%
insta_filter = ("none","glory","buty","robotics","colur")
insta_filter[0] = "abc"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 insta_filter = ("none","glory","buty","robotics","colur")
# ----> 2 insta_filter[0] = "abc"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # question 5

# %%
zomato_order_ids = [12,5268,35,49,65] # here we use lst becos if order was complited then we remove it and if new one is come we want to add it 
ipl_teams = ("csk","rcb","mi","gt","dc","pks") # here we use toupple becus ipl team are fix during one seson 
print (f"currunt zomato orders ids : {zomato_order_ids}")
print (f"currunt seson ipl teams : {ipl_teams}")
# hear are more examples of list and toupple 
# list : order ditails , railway curront train pacengers , playing players name , salling products
# toupple : store constans in maths , avalable train routs , name of roals in one compony , compony all personal info ( like name , gst no, etc )
# there more then this examples are avlable
# Out:
# currunt zomato orders ids : [12, 5268, 35, 49, 65]
# currunt seson ipl teams : ('csk', 'rcb', 'mi', 'gt', 'dc', 'pks')
