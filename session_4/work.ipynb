# %% [markdown]
# # question 1

# %%
s = 'Flipcart_Sall2024'
s=s.lower()
s=s.replace('_', ' ')
s
# Out:
# 'flipcart sall2024'

# %% [markdown]
# # question 2

# %%
s = 'OnePlus Nord-CE 3     '
s = s.strip()
s = s.upper()
s = s.replace('-',',')
s
# Out:
# 'ONEPLUS NORD,CE 3'

# %% [markdown]
# # question 3

# %%
product_code = 'ZOMATO-FOOD-2024'
def split_product_code (product_code) :
    return product_code.split('-')
split_product_code(product_code)
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %% [markdown]
# # question 4

# %%
s = 'Spotify_Premium_Offer'
s[8:15]
# Out:
# 'Spotify_Premium_Offer'

# %% [markdown]
# # question 5

# %%
product = "Myntra shirt"
price = 799
print(f"deal: {product} is avalble at {price} only!")
# Out:
# deal: Myntra shirt is avalble at 799 only!
