# %% [markdown]
# # question 1

# %%
l1 = [
    'chat on wahtsapp',
    'scrole reel in instagram',
    'order food on zomato',
    'playing games',
    'use google for daily repot'
]

# %% [markdown]
# # question 2

# %%
music_data = ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']
print("this data is qulitative data becouse this data is used to define the catagory of music. \n and this data define how music is actuly was.")
# Out:
# this data is qulitative data becouse this data is used to define the catagory of music.
#  and this data define how music is actuly was.

# %% [markdown]
# # question 3

# %%
print ("in fetures like amazon rating  and like on instaf=gram like we used statastic and try to pridict how was product or content and what \n type of people are used it or how peoples are rect  on it ")
# Out:
# in fetures like amazon rating  and like on instaf=gram like we used statastic and try to pridict how was product or content and what
#  type of people are used it or how peoples are rect  on it

# %% [markdown]
# # question 4

# %%
print("i was like to use this three statastical feture \n")
print("mean : which average langth of music or plalist user like most")
print("mode : to identify which track user like most")
print("variance : to identify around which freqncy was user like most ")
# Out:
# i was like to use this three statastical feture
#
# mean : which average langth of music or plalist user like most
# mode : to identify which track user like most
# variance : to identify around which freqncy was user like most
