# %% [markdown]
# # question 1

# %%
insta_followers = {
    "abc" : 123 ,
    "kjr" : 586 ,
    "olt" : 689 ,
    "otk" : 245 ,
    "hjk" : 1000 ,
}
insta_followers
# Out:
# {'abc': 123, 'kjr': 586, 'olt': 689, 'otk': 245, 'hjk': 1000}

# %% [markdown]
# # question 2

# %%
insta_followers ["kit"] = 157
for i in insta_followers :
    insta_followers[i] = insta_followers[i]+1
insta_followers.pop("abc")
insta_followers
# Out:
# {'kjr': 587, 'olt': 690, 'otk': 246, 'hjk': 1001, 'kit': 158}

# %% [markdown]
# # question 3

# %%
swiggy_food_price = {
    "pizza" : 250 ,
    "chole_bhature" : 150 ,
    "nudeles" : 100 ,
    "thali" : 280 ,
    "pasta" : 299 ,
}
for i in swiggy_food_price : 
    if swiggy_food_price[i] >= 200 :
        print(i)
# Out:
# pizza
# thali
# pasta

# %% [markdown]
# # question 4

# %%
flipcart_usrs = {'abc','hgj','yuo','fuh','yur'}
myenta_user = {'abc','khj','yuo','hrk','rge'}
flipcart_usrs.intersection(myenta_user)
# Out:
# {'abc', 'yuo'}

# %% [markdown]
# # question 5

# %%
def get_unique_artiest_name (spodify_plalist_1,spodify_plalist_2) :
    return spodify_plalist_1.union(spodify_plalist_2)
spodify_plalist_1 = {'sjh','ijr','ighr','hfhf','hry'}
spodify_plalist_2 = {'sjh','jfu','uty','hfhf','yrj'}
get_unique_artiest_name(spodify_plalist_1 , spodify_plalist_2)
# Out:
# {'hfhf', 'hry', 'ighr', 'ijr', 'jfu', 'sjh', 'uty', 'yrj'}
