# %% [markdown]
# # question 1

# %%
name = "thakkar harsh "
age = 19
hight = 171.23
is_spodify = True 
print ("your name :", name , type(name))
print ("your age is :",age , type(age))
print("your hight is :",hight, type(hight))
print("are you have spodify account :", is_spodify,type(is_spodify))
# Out:
# your name : thakkar harsh  <class 'str'>
# your age is : 19 <class 'int'>
# your hight is : 171.23 <class 'float'>
# are you have spodify account : True <class 'bool'>

# %% [markdown]
# # question 2

# %%
def total_cart_amount(price):
    sum = 0
    for i in range(len(price)):
        sum = sum + float(price[i])
    print(sum)

price = ['199.99','49','350.75']
total_cart_amount(price)
# Out:
# 599.74

# %% [markdown]
# # question 3

# %%
score = int(input("enter your score : "))
if score >= 50 : 
    print("Half century !")
else :
    print("Keep going")
# Out:
# Keep going

# %% [markdown]
# # question 4

# %%
is_premium = 'True'
is_premium_a = is_premium
bool(is_premium_a)
if is_premium == 'True':
   is_premium = bool(is_premium)
elif is_premium == 'False':
    is_premium = bool(is_premium)
    is_premium = False
else :
    print("conversion is nort possible ")
print(is_premium)
type(is_premium)
# Out:
# True
# bool
